# %% [markdown]
# **Links:**
#
# https://www.google.com/
#
# <https://www.google.com/>
#
# [Google home page](https://www.google.com/)

# %% [markdown]
# In this example we'll go over some code that recreates a hypothetical problem that ilustrate what happens when we sample from an entire population.
# The data we'll be using is a just a simulation so values are made up.
# The population we are analyzing is the students of a university. The variable is their weight, of students who go to the gym and students who don't.

# %%
import numpy as np
import matplotlib.pyplot as plt  
import seaborn as sns; sns.set()

# %%
# Data

non_gym_mein_weight = 155
sd_non_gym = 5
gym_mein_weight = 185 
sd_gym = 5 
gym_percent = .3
total_pop = 40000

# Subgroups

non_gym_students = np.random.normal(non_gym_mein_weight, sd_non_gym, int(total_pop * (1 - gym_percent)))
students_at_gym = np.random.normal(gym_mein_weight, sd_gym, int(total_pop * (gym_percent)))
population = np.append(non_gym_students, students_at_gym)

# %% [markdown]
# **Entire population**

# %%
plt.figure(figsize=(10,12))

# Non gym students plot
plt.subplot(3,1,1)
sns.distplot(non_gym_students)
plt.title("Non gym students")
plt.xlim([140,200])

# Gym students plot
plt.subplot(3,1,2)
sns.distplot(students_at_gym)
plt.title("Gym Goers Only")
plt.xlim([140,200])

# Entire population plot
plt.subplot(3,1,3)
sns.distplot(population)
plt.title("Full Population of Students")
plt.axvline(x = np.mean(population))
plt.xlim([140,200])
# Out:
# (140, 200)

# %% [markdown]
# **Sampling from the entire population randomly**

# %%
# Simulation parameters
number_samps = 5000
samp_size = 50

# Get the sampling distribution of the mean from only the gym
mean_distribution = np.empty(number_samps)
for i in range(number_samps):
    random_students = np.random.choice(population, samp_size)
    mean_distribution[i] = np.mean(random_students)
    
# Plot the population and the biased sampling distribution
plt.figure(figsize = (10,8))

# Plotting the population again
plt.subplot(2,1,1)
sns.distplot(population)
plt.title("Full Population of Students")
plt.axvline(x = np.mean(population))
plt.xlim([140,200])

# Plotting the sampling distribution
plt.subplot(2,1,2)
sns.distplot(mean_distribution)
plt.title("Sampling Distribution of the Mean Weight of All UofM Students")
plt.axvline(x = np.mean(population), color = "yellow")
plt.axvline(x = np.mean(mean_distribution), color = "black")
plt.xlim([140,200])

print()

plt.show()
